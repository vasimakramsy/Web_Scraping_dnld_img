# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://levelup.gitconnected.com/quick-web-scraping-with-python-beautiful-soup-4dde18468f1f'

html = requests.get(url)

# %%
html.content
# Out:
# b'<!doctype html><html lang="en"><head><script>!function(c,f){var t,o,i,e=[],r={passive:!0,capture:!0},n=new Date,a="pointerup",u="pointercancel";function p(n,e){t||(t=e,o=n,i=new Date,w(f),s())}function s(){0<=o&&o<i-n&&(e.forEach(function(n){n(o,t)}),e=[])}function l(n){if(n.cancelable){var e=(1e12<n.timeStamp?new Date:performance.now())-n.timeStamp;"pointerdown"==n.type?function(n,e){function t(){p(n,e),i()}function o(){i()}function i(){f(a,t,r),f(u,o,r)}c(a,t,r),c(u,o,r)}(e,n):p(e,n)}}function w(e){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(n){e(n,l,r)})}w(c),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){e.push(n),s()}}(addEventListener,removeEventListener)</script><title data-rh="true">Quick Web Scraping with Python and Beautiful Soup - Level Up Coding</title><meta data-rh="true" charset="utf-8"/><meta data-rh="true" name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1"/><meta data-rh="true" name="theme-color" content="#000000"/><meta data-rh="true" name="twitter:app:name:iphone" content="Medium"/><meta data-rh="true" name="twitter:app:id:iphone" content="828256236"/><meta data-rh="true" property="al:ios:app_name" content="Medium"/><meta data-rh="true" property="al:ios:app_store_id" content="828256236"/><meta data-rh="true" property="al:android:package" content="com.medium.reader"/><meta data-rh="true" property="fb:app_id" content="542599432471018"/><meta data-rh="true" property="og:site_name" content="Medium"/><meta data-rh="true" property="og:type" content="article"/><meta data-rh="true" property="article:published_time" content="2019-06-18T07:18:32.914Z"/><meta data-rh="true" name="title" content="Quick Web Scraping with Python and Beautiful Soup - Level Up Coding"/><meta data-rh="true" property="og:title" content="Quick Web Scraping with Python &amp; Beautiful Soup"/><meta data-rh="true" property="twitter:title" content="Quick Web Scraping with Python &amp; Beautiful Soup"/><meta data-rh="true" name="twitter:site" content="@gitconnected"/><meta data-rh="true" name="twitter:app:url:iphone" content="medium://p/4dde18468f1f"/><meta data-rh="true" property="al:android:url" content="medium://p/4dde18468f1f"/><meta data-rh="true" property="al:ios:url" content="medium://p/4dde18468f1f"/><meta data-rh="true" property="al:android:app_name" content="Medium"/><meta data-rh="true" name="description" content="Web scraping allows you to download the HTML of a website and extract the data that you need. Using Python with Beautiful Soup is an excellent way to scrape the web. One of the many packages you\xe2\x80\xa6"/><meta data-rh="true" property="og:description" content="Let\xe2\x80\x99s say you want to extract and process a certain amount of data from the website. Whether you are a data scientist or not, as long as\xe2\x80\xa6"/><meta data-rh="true" property="twitter:description" content="Let\xe2\x80\x99s say you want to extract and process a certain amount of data from the website. Whether you are a data scientist or not, as long as\xe2\x80\xa6"/><meta data-rh="true" property="og:url" content="https://levelup.gitconnected.com/quick-web-scraping-with-python-beautiful-soup-4dde18468f1f"/><meta data-rh="true" property="al:web:url" content="https://levelup.gitconnected.com/quick-web-scraping-with-python-beautiful-soup-4dde18468f1f"/><meta data-rh="true" property="og:image" content="https://miro.medium.com/max/490/1*NZz995dKNIjXnRqDroCqWg.png"/><meta data-rh="true" name="twitter:image:src" content="https://miro.medium.com/max/490/1*NZz995dKNIjXnRqDroCqWg.png"/><meta data-rh="true" name="twitter:card" content="summary_large_image"/><meta data-rh="true" property="article:author" content="https://levelup.gitconnected.com/@yunhanh"/><meta data-rh="true" name="author" content="Hannah Huang"/><meta data-rh="true" name="robots" content="index,follow"/><meta data-rh="true" name="referrer" content="unsafe-url"/><meta data-rh="true" name="twitter:label ...

# %%
soup = BeautifulSoup(html.content)

# %%
soup.find_all('p')
# Out:
# [<p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="2e74">Web scraping allows you to download the HTML of a website and extract the data that you need. Using Python with Beautiful Soup is an excellent way to scrape the web.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="60de">One of the many packages you could use while doing data scraping is Beautiful Soup. Beautiful Soup is a python package for parsing HTML and XML documents and extracting data. To perform web scraping, we also need <code class="hh ip iq ir is b">urllib</code> to connect the webpage.</p>,
#  <p class="hn ho ef at hp b hq it hs iu hu iv hw iw hy ix ia" id="422c">First, install the following python packages.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="5175">Then, we can start importing all the necessary packages.</p>,
#  <p class="hn ho ef at hp b hq it hs iu hu iv hw iw hy ix ia" id="a4d8">There are three objects under <code class="hh ip iq ir is b">BeautifulSoup</code>:</p>,
#  <p class="hn ho ef at hp b hq it hs iu hu iv hw iw hy ix ia" id="fa32">There are two ways to create your <code class="hh ip iq ir is b">BeautifulSoup</code> object.</p>,
#  <p class="hn ho ef at hp b hq it hs iu hu iv hw iw hy ix ia" id="a542">Let’s use BeautifulSoup to do a simple data extraction. Say I want to have a quick glance of the Boston University facts and statistics on their <a class="dc by kd ke kf kg" href="http://www.bu.edu/president/boston-university-facts-stats/" rel="noopener" target="_blank">website</a>.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="90ea">First, we want to obtain the title of this website.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="bcc2">This will print out the text of the title:</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="8e6c">If you don’t do the final step <code class="hh ip iq ir is b">titleText = title.get_text()</code>, your web scraper will give you the following result instead of a clean text.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="be87">There are many ways that BeautifulSoup allows you to find specific elements. Here are some of the common ones:</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="67c2">BeautifulSoup is powerful enough to do any data extraction you can think of. Here are some other simple data extractions you can do with it:</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="9213">In this example we only need <code class="hh ip iq ir is b">find()</code> and <code class="hh ip iq ir is b">find_all()</code> to find specific data.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="50bc"><code class="hh ip iq ir is b">find_all()</code> allows you to obtain <strong class="hp kk">all</strong> the elements based on the restrictions you put inside the parenthesis.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="d4b3"><code class="hh ip iq ir is b">find()</code> allows you to extract the very <strong class="hp kk">first</strong> element that satisfies your restriction.</p>,
#  <p class="hn ho ef at hp b hq it hs iu hu iv hw iw hy ix ia" id="c20d">Right-click anywhere on the webpage and go to “inspect” and select the element that we want to inspect. There is a <code class="hh ip iq ir is b">&lt;section class = "facts-categories"&gt;</code> that consists of multiple <code class="hh ip iq ir is b">div</code> tags.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="3b31">Each div tags has corresponding data that we want to obtain, and what we need to do is to use BeautifulSoup to go to the section, and then find all the data content in each <code class="hh ip iq ir is b">&lt;div class = "facts-wrapper"&gt;</code>. We can use <code class="hh ip iq ir is b">find_all()</code> to do that.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="5af3">By doing this, we are now in the range of the section whose CSS class is <code class="hh ip iq ir is b">facts-categories</code>. Next, we want to loop over our web scraper to every single <code class="hh ip iq ir is b">div</code> tags under this section, which contains two parts: a sub-category, in <code class="hh ip iq ir is b">&lt;h5&gt;&lt;/h5&gt;</code> tag, and the corresponding data under this sub-category, which can be found in <code class="hh ip iq ir is b">&lt;li class = "list-item"&gt;</code>.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="c221">For example, here we have the first sub-category: “Community”, it contains data about Student Body, Living Alumni, Total Employees…etc.</p>,
#  <p class="hn ho ef at hp b hq it hs iu hu iv hw iw hy ix ia" id="1272">We want to construct a nested loop for the web scraper to iterate every single list that contains our desired data.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="3bce">Awesome, now we can put the code into a function and run it. Part of the result we get will look like this:</p>,
#  <p class="hn ho ef at hp b hq it hs iu hu iv hw iw hy ix ia" id="0ee4">Python and BeautifulSoup package make web scraping much easier.</p>,
#  <p class="hn ho ef at hp b hq hr hs ht hu hv hw hx hy hz ia" id="b030">Hopefully this simple web scraping example gives you an introduction of BeautifulSoup and some idea of building a basic web scraper.</p>,
#  <p class="as cx cy au ax da no">Written by</p>]

# %%
soup.find('title')
# Out:
# <title data-rh="true">Quick Web Scraping with Python and Beautiful Soup - Level Up Coding</title>

# %%
soup.find('html')
# Out:
# <html lang="en"><head><script>!function(c,f){var t,o,i,e=[],r={passive:!0,capture:!0},n=new Date,a="pointerup",u="pointercancel";function p(n,e){t||(t=e,o=n,i=new Date,w(f),s())}function s(){0<=o&&o<i-n&&(e.forEach(function(n){n(o,t)}),e=[])}function l(n){if(n.cancelable){var e=(1e12<n.timeStamp?new Date:performance.now())-n.timeStamp;"pointerdown"==n.type?function(n,e){function t(){p(n,e),i()}function o(){i()}function i(){f(a,t,r),f(u,o,r)}c(a,t,r),c(u,o,r)}(e,n):p(e,n)}}function w(e){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(n){e(n,l,r)})}w(c),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){e.push(n),s()}}(addEventListener,removeEventListener)</script><title data-rh="true">Quick Web Scraping with Python and Beautiful Soup - Level Up Coding</title><meta charset="utf-8" data-rh="true"/><meta content="width=device-width,minimum-scale=1,initial-scale=1" data-rh="true" name="viewport"/><meta content="#000000" data-rh="true" name="theme-color"/><meta content="Medium" data-rh="true" name="twitter:app:name:iphone"/><meta content="828256236" data-rh="true" name="twitter:app:id:iphone"/><meta content="Medium" data-rh="true" property="al:ios:app_name"/><meta content="828256236" data-rh="true" property="al:ios:app_store_id"/><meta content="com.medium.reader" data-rh="true" property="al:android:package"/><meta content="542599432471018" data-rh="true" property="fb:app_id"/><meta content="Medium" data-rh="true" property="og:site_name"/><meta content="article" data-rh="true" property="og:type"/><meta content="2019-06-18T07:18:32.914Z" data-rh="true" property="article:published_time"/><meta content="Quick Web Scraping with Python and Beautiful Soup - Level Up Coding" data-rh="true" name="title"/><meta content="Quick Web Scraping with Python &amp; Beautiful Soup" data-rh="true" property="og:title"/><meta content="Quick Web Scraping with Python &amp; Beautiful Soup" data-rh="true" property="twitter:title"/><meta content="@gitconnected" data-rh="true" name="twitter:site"/><meta content="medium://p/4dde18468f1f" data-rh="true" name="twitter:app:url:iphone"/><meta content="medium://p/4dde18468f1f" data-rh="true" property="al:android:url"/><meta content="medium://p/4dde18468f1f" data-rh="true" property="al:ios:url"/><meta content="Medium" data-rh="true" property="al:android:app_name"/><meta content="Web scraping allows you to download the HTML of a website and extract the data that you need. Using Python with Beautiful Soup is an excellent way to scrape the web. One of the many packages you…" data-rh="true" name="description"/><meta content="Let’s say you want to extract and process a certain amount of data from the website. Whether you are a data scientist or not, as long as…" data-rh="true" property="og:description"/><meta content="Let’s say you want to extract and process a certain amount of data from the website. Whether you are a data scientist or not, as long as…" data-rh="true" property="twitter:description"/><meta content="https://levelup.gitconnected.com/quick-web-scraping-with-python-beautiful-soup-4dde18468f1f" data-rh="true" property="og:url"/><meta content="https://levelup.gitconnected.com/quick-web-scraping-with-python-beautiful-soup-4dde18468f1f" data-rh="true" property="al:web:url"/><meta content="https://miro.medium.com/max/490/1*NZz995dKNIjXnRqDroCqWg.png" data-rh="true" property="og:image"/><meta content="https://miro.medium.com/max/490/1*NZz995dKNIjXnRqDroCqWg.png" data-rh="true" name="twitter:image:src"/><meta content="summary_large_image" data-rh="true" name="twitter:card"/><meta content="https://levelup.gitconnected.com/@yunhanh" data-rh="true" property="article:author"/><meta content="Hannah Huang" data-rh="true" name="author"/><meta content="index,follow" data-rh="true" name="robots"/><meta content="unsafe-url" data-rh="true" name="referrer"/><meta data-rh="true" name="twitter:label1" value="Reading time"/><meta data-rh="true" name="twitter:data1" value ...
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-24232453-2', 'auto');
# ga('send', 'pageview');</script><link as="script" href="https://cdn.optimizely.com/js/16180790160.js" rel="preload"/><style data-fela-rehydration="433" data-fela-type="STATIC" type="text/css">html{box-sizing:border-box}*, *:before, *:after{box-sizing:inherit}body{margin:0;padding:0;text-rendering:optimizeLegibility;-webkit-font-smoothing:antialiased;color:rgba(0,0,0,0.8);position:relative;min-height:100vh}h1, h2, h3, h4, h5, h6, dl, dd, ol, ul, menu, figure, blockquote, p, pre, form{margin:0}menu, ol, ul{padding:0;list-style:none;list-style-image:none}main{display:block}a{color:inherit;text-decoration:none}a, button, input{-webkit-tap-highlight-color:transparent}img, svg{vertical-align:middle}button{background:transparent;overflow:visible}button, input, optgroup, select, textarea{margin:0}</style><style data-fela-rehydration="433" data-fela-type="KEYFRAME" type="text/css">@-webkit-keyframes k1{0%{transform:scale(1);opacity:1}70%{transform:scale(1.4);opacity:0}100%{opacity:0}}@-moz-keyframes k1{0%{transform:scale(1);opacity:1}70%{transform:scale(1.4);opacity:0}100%{opacity:0}}@keyframes k1{0%{transform:scale(1);opacity:1}70%{transform:scale(1.4);opacity:0}100%{opacity:0}}</style><style data-fela-rehydration="433" data-fela-type="RULE" type="text/css">.a{font-family:medium-content-sans-serif-font, -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Oxygen, Ubuntu, Cantarell, "Open Sans", "Helvetica Neue", sans-serif}.b{font-weight:400}.c{background-color:rgba(255, 255, 255, 1)}.l{height:100vh}.m{width:100vw}.n{display:flex}.o{align-items:center}.p{justify-content:center}.q{fill:rgba(0, 0, 0, 0.84)}.r{display:block}.s{position:fixed}.t{top:0}.u{left:0}.v{right:0}.w{z-index:500}.x{box-shadow:0 4px 12px 0 rgba(0, 0, 0, 0.05)}.ai{max-width:1192px}.aj{min-width:0}.ak{width:100%}.al{height:65px}.ao{flex:1 0 auto}.ap{flex:0 0 auto}.aq{visibility:hidden}.ar{margin-left:16px}.as{font-family:medium-content-sans-serif-font, "Lucida Grande", "Lucida Sans Unicode", "Lucida Sans", Geneva, Arial, sans-serif}.at{font-style:normal}.au{line-height:20px}.av{font-size:15.8px}.aw{letter-spacing:0px}.ax{color:rgba(0, 0, 0, 0.54)}.ay{fill:rgba(0, 0, 0, 0.54)}.az{color:rgba(69, 114, 201, 1)}.ba{fill:rgba(75, 132, 243, 1)}.bb{font-size:inherit}.bc{border:inherit}.bd{font-family:inherit}.be{letter-spacing:inherit}.bf{font-weight:inherit}.bg{padding:0}.bh{margin:0}.bi:hover{cursor:pointer}.bj:hover{color:rgba(66, 105, 181, 1)}.bk:hover{fill:rgba(69, 114, 201, 1)}.bl:focus{outline:none}.bm:disabled{cursor:default}.bn:disabled{color:rgba(3, 168, 124, 0.5)}.bo:disabled{fill:rgba(3, 168, 124, 0.5)}.bp{padding:8px 16px}.bq{background:0}.br{border-color:rgba(75, 132, 243, 1)}.bs:hover{border-color:rgba(69, 114, 201, 1)}.bt{border-radius:4px}.bu{border-width:1px}.bv{border-style:solid}.bw{box-sizing:border-box}.bx{display:inline-block}.by{text-decoration:none}.bz{border-top:none}.ca{background-color:rgba(57, 114, 224, 1)}.cc{height:54px}.cd{overflow:hidden}.ce{margin-right:40px}.cf{height:36px}.cg{width:245px}.ch{overflow:auto}.ci{flex:0 1 auto}.cj{list-style-type:none}.ck{line-height:40px}.cl{white-space:nowrap}.cm{overflow-x:auto}.cn{align-items:flex-start}.co{margin-top:20px}.cp{padding-top:20px}.cq{height:80px}.cr{height:20px}.cs{margin-right:15px}.ct{margin-left:15px}.cu:first-child{margin-left:0}.cv{min-width:1px}.cw{background-color:rgba(195, 218, 255, 1)}.cx{font-weight:300}.cy{font-size:15px}.cz{color:rgba(195, 218, 255, 1)}.da{text-transform:uppercase}.db{letter-spacing:1px}.dc{color:inherit}.dd{fill:inherit}.de:hover{color:rgba(246, 255, 255, 1)}.df:hover{fill:rgba(230, 243, 255, 1)}.dg:disabled{color:rgba(150, 184, 250, 1)}.dh:disabled{fill:rgba(150, 184, 250, 1)}.di{margin-bottom:0px}.dj{height:119px}.dm{padding-left:24px}.dn{padding-right:24px}.do{margin-left:auto}.dp{margin-right:auto}.dq{max-width:728px}.dr{flex-direction:column}.ds{position:absolute}.dt{top:calc(100vh + 100px)}.du{bottom:calc(100vh + 100px)}.dv{width:10px}.dw{pointer-events:n ...
#       radial-gradient(circle, rgba(69, 114, 201, 1) 60%, transparent 70%)
#     }.mp::before{border-radius:50%}.mq::before{content:""}.mr::before{display:block}.ms::before{z-index:0}.mt::before{left:0}.mu::before{height:100%}.mv::before{position:absolute}.mw::before{top:0}.mx::before{width:100%}.my:hover::before{animation:k1 2000ms infinite cubic-bezier(.1,.12,.25,1)}.nb{transition:fill 200ms ease}</style><style data-fela-rehydration="433" data-fela-type="RULE" media="all and (max-width: 1230px)" type="text/css">.la{display:none}</style><style data-fela-rehydration="433" data-fela-type="RULE" media="all and (max-width: 1198px)" type="text/css">.lc{display:none}</style></head><body><div id="root"><div class="a b c"><div class="d e f g h i j k"></div><script>document.domain = document.domain;</script><script>window.PARSELY = window.PARSELY || {autotrack: false}</script><nav class="r s t u v c w x y z ab"><div class="branch-journeys-top"><div class="r c"><div class="n p"><div class="ac ae af ag ah ai aj ak"><div class="al n o am an"><div class="n o ao w"><a aria-label="Homepage" href="https://medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><svg class="q" height="35" viewBox="5 5 35 35" width="35"><path d="M5 40V5h35v35H5zm8.56-12.63c0 .56-.03.69-.32 1.03L10.8 31.4v.4h6.97v-.4L15.3 28.4c-.29-.34-.34-.5-.34-1.03v-8.95l6.13 13.36h.71l5.26-13.36v10.64c0 .3 0 .35-.19.53l-1.85 1.8v.4h9.2v-.4l-1.83-1.8c-.18-.18-.2-.24-.2-.53V15.94c0-.3.02-.35.2-.53l1.82-1.8v-.4h-6.47l-4.62 11.55-5.2-11.54h-6.8v.4l2.15 2.63c.24.3.29.37.29.77v10.35z"></path></svg></a></div><div class="r ap w"><div class="n o"><div class="n g"><div class="aq" id="lo-post-page-navbar-sign-in-link"><div class="ar r"><span class="as b at au av aw r ax ay"><a class="az ba bb bc bd be bf bg bh bi bj bk bl bm bn bo" href="https://medium.com/m/signin?operation=login&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_page-----4dde18468f1f---------------------nav_reg-" rel="noopener">Sign in</a></span></div></div></div><div class="aq" id="lo-post-page-navbar-get-started-button"><div class="ar r"><a class="bp bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_page-----4dde18468f1f---------------------nav_reg-" rel="noopener">Get started</a></div></div></div></div></div></div></div></div><div class="bz r ca cb"><div class="n p"><div class="ac ae af ag ah ai aj ak"><div class="cc cd n o"><div class="ce r ap"><a href="https://levelup.gitconnected.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><div class="cf cg r"><img alt="Level Up Coding" class="" height="36" src="https://miro.medium.com/max/490/1*9EJ1XEKLx0P1-ey1Fmc6vg.png" width="245"/></div></a></div><div class="ch r ci"><ul class="cj bh ck cl cm n cn g co cp cq"><li class="n o cr cs ct cu"><span class="as cx cy au cz da db"><a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="/how-to-get-published-on-gitconnected-dac547ef556b?source=post_page-----4dde18468f1f----------------------" rel="noopener">WRITE FOR US</a></span></li><li class="n o cr cs ct cu"><span class="as cx cy au cz da db"><a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="/the-2020-web-developer-roadmap-76503ddfb327?source=post_page-----4dde18468f1f----------------------" rel="noopener">Web Dev Roadmap 2020</a></span></li><span class="cr cv cw"></span><li class="n o cr cs ct cu"><span class="as cx cy au cz da db"><a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="https://gitconnected.com/portfolio-api?utm_source=medium&amp;utm_medium=nav&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener">Your Dev Portfolio API →</a></span></li></ul></div></div></div></div></div></div></nav><div class="di dj r dk dl"></div><article><section class="dm dn do dp ak d ...
# <script src="https://cdn-client.medium.com/lite/static/js/screen.collection.packageBuilder~screen.landingpages.pres45~screen.landingpages.tribute~screen.post~~4767c889.4d21fc30.chunk.js"></script>
# <script src="https://cdn-client.medium.com/lite/static/js/screen.collection.packageBuilder~screen.landingpages.pres45~screen.landingpages.tribute~screen.post~~73c4bb05.7c8a8baf.chunk.js"></script>
# <script src="https://cdn-client.medium.com/lite/static/js/screen.post~screen.post.amp~screen.profile~screen.sequence.library~screen.sequence.post~screen.stori~aba94ffa.c7982213.chunk.js"></script>
# <script src="https://cdn-client.medium.com/lite/static/js/screen.post.b1a02927.chunk.js"></script><script>window.main();</script></body></html>

# %%
soup.find_all('a')
# Out:
# [<a aria-label="Homepage" href="https://medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><svg class="q" height="35" viewBox="5 5 35 35" width="35"><path d="M5 40V5h35v35H5zm8.56-12.63c0 .56-.03.69-.32 1.03L10.8 31.4v.4h6.97v-.4L15.3 28.4c-.29-.34-.34-.5-.34-1.03v-8.95l6.13 13.36h.71l5.26-13.36v10.64c0 .3 0 .35-.19.53l-1.85 1.8v.4h9.2v-.4l-1.83-1.8c-.18-.18-.2-.24-.2-.53V15.94c0-.3.02-.35.2-.53l1.82-1.8v-.4h-6.47l-4.62 11.55-5.2-11.54h-6.8v.4l2.15 2.63c.24.3.29.37.29.77v10.35z"></path></svg></a>,
#  <a class="az ba bb bc bd be bf bg bh bi bj bk bl bm bn bo" href="https://medium.com/m/signin?operation=login&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_page-----4dde18468f1f---------------------nav_reg-" rel="noopener">Sign in</a>,
#  <a class="bp bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_page-----4dde18468f1f---------------------nav_reg-" rel="noopener">Get started</a>,
#  <a href="https://levelup.gitconnected.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><div class="cf cg r"><img alt="Level Up Coding" class="" height="36" src="https://miro.medium.com/max/490/1*9EJ1XEKLx0P1-ey1Fmc6vg.png" width="245"/></div></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="/how-to-get-published-on-gitconnected-dac547ef556b?source=post_page-----4dde18468f1f----------------------" rel="noopener">WRITE FOR US</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="/the-2020-web-developer-roadmap-76503ddfb327?source=post_page-----4dde18468f1f----------------------" rel="noopener">Web Dev Roadmap 2020</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="https://gitconnected.com/portfolio-api?utm_source=medium&amp;utm_medium=nav&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener">Your Dev Portfolio API →</a>,
#  <a href="/@yunhanh?source=post_page-----4dde18468f1f----------------------" rel="noopener"><img alt="Hannah Huang" class="r fc fd fe" height="48" src="https://miro.medium.com/fit/c/96/96/1*Vy9pmdUSKQjWdPz79tfaOw@2x.jpeg" width="48"/></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi fo bl bm fp fq" href="/@yunhanh?source=post_page-----4dde18468f1f----------------------" rel="noopener">Hannah Huang</a>,
#  <a class="fs ef q bq ft fu fv fw bi fp fx fy fz ga gb gc bt as b at gd cy aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=-b3c4a67e76b6-------------------------follow_byline-" rel="noopener">Follow</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi fo bl bm fp fq" href="/quick-web-scraping-with-python-beautiful-soup-4dde18468f1f?source=post_page-----4dde18468f1f----------------------" rel="noopener">Jun 15, 2019</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/twitter?source=post_actions_header---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M22.05 7.54a4.47 4.47 0 0 0-3.3-1.46 4.53 4.53 0 0 0-4.53 4.53c0 .35.04.7.08 1.05A12.9 12.9 0 0 1 5 6.89a5.1 5.1 0 0 0-.65 2.26c.03 1.6.83 2.99 2.02 3.79a4.3 4.3 0 0 1-2.02-.57v.08a4.55 4.55 0 0 0 3.63 4.44c-.4.08-.8.13-1.21.16l-.81-.08a4.54 4.54 0 0 0 4.2 3.15 9.56 9.56 0 0 1-5.66 1.94l-1.05-.08c2 1.27 4.38 2.02 6.94 2.02 8.3 0 12.86-6.9 12.84-12.85.02-.24 0-.43 0-.65a8.68 8.68 0 0 0 2.26-2.34c-.82.38-1.7.62-2.6.72a4.37 4.37 0 0 0 1.95-2.51c-.84.53-1.81.9-2.83 1.13z"></path></svg></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/facebook?source=post_actions_header---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M23.2 5H5.8a.8.8 0 0 0-.8.8V23.2c0 .44.35.8.8.8h9.3v-7.13h-2.38V13.9h2.38v-2.38c0-2.45 1.55-3.66 3.74-3.66 1.05 0 1.95.08 2.2.11v2.57h-1.5c-1.2 0-1.48.57-1.48 1.4v1.96h2.97l-.6 2.97h-2.37l.05 7.12h5.1a.8.8 0 0 0 .79-.8V5.8a.8.8 0 0 0-.8-.79"></path></svg></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_actions_header--------------------------bookmark_sidebar-" rel="noopener"><svg height="25" viewBox="0 0 25 25" width="25"><path d="M19 6a2 2 0 0 0-2-2H8a2 2 0 0 0-2 2v14.66h.01c.01.1.05.2.12.28a.5.5 0 0 0 .7.03l5.67-4.12 5.66 4.13a.5.5 0 0 0 .71-.03.5.5 0 0 0 .12-.29H19V6zm-6.84 9.97L7 19.64V6a1 1 0 0 1 1-1h9a1 1 0 0 1 1 1v13.64l-5.16-3.67a.49.49 0 0 0-.68 0z" fill-rule="evenodd"></path></svg></a>,
#  <a class="dc by kd ke kf kg" href="http://www.bu.edu/president/boston-university-facts-stats/" rel="noopener" target="_blank">website</a>,
#  <a class="dc by kd ke kf kg" href="http://www.bu.edu/president/boston-university-facts-stats/" rel="noopener" target="_blank">http://www.bu.edu/president/boston-university-facts-stats/</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://levelup.gitconnected.com/?source=post_sidebar--------------------------post_sidebar-" rel="noopener"><h2 class="as id lg au ef">Level Up Coding</h2></a>,
#  <a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_sidebar--------------------------follow_sidebar-" rel="noopener">Follow</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_sidebar-----4dde18468f1f---------------------clap_sidebar-" rel="noopener"><div class="bg lq lr ls lt lu lv lw ba lx bk"><svg height="29" width="29"><g fill-rule="evenodd"><path d="M13.74 1l.76 2.97.76-2.97zM16.82 4.78l1.84-2.56-1.43-.47zM10.38 2.22l1.84 2.56-.41-3.03zM22.38 22.62a5.11 5.11 0 0 1-3.16 1.61l.49-.45c2.88-2.89 3.45-5.98 1.69-9.21l-1.1-1.94-.96-2.02c-.31-.67-.23-1.18.25-1.55a.84.84 0 0 1 .66-.16c.34.05.66.28.88.6l2.85 5.02c1.18 1.97 1.38 5.12-1.6 8.1M9.1 22.1l-5.02-5.02a1 1 0 0 1 .7-1.7 1 1 0 0 1 .72.3l2.6 2.6a.44.44 0 0 0 .63-.62L6.1 15.04l-1.75-1.75a1 1 0 1 1 1.41-1.41l4.15 4.15a.44.44 0 0 0 .63 0 .44.44 0 0 0 0-.62L6.4 11.26l-1.18-1.18a1 1 0 0 1 0-1.4 1.02 1.02 0 0 1 1.41 0l1.18 1.16L11.96 14a.44.44 0 0 0 .62 0 .44.44 0 0 0 0-.63L8.43 9.22a.99.99 0 0 1-.3-.7.99.99 0 0 1 .3-.7 1 1 0 0 1 1.41 0l7 6.98a.44.44 0 0 0 .7-.5l-1.35-2.85c-.31-.68-.23-1.19.25-1.56a.85.85 0 0 1 .66-.16c.34.06.66.28.88.6L20.63 15c1.57 2.88 1.07 5.54-1.55 8.16a5.62 5.62 0 0 1-5.06 1.65 9.35 9.35 0 0 1-4.93-2.72zM13 6.98l2.56 2.56c-.5.6-.56 1.41-.15 2.28l.26.56-4.25-4.25a.98.98 0 0 1-.12-.45 1 1 0 0 1 .29-.7 1.02 1.02 0 0 1 1.41 0zm8.89 2.06c-.38-.56-.9-.92-1.49-1.01a1.74 1.74 0 0 0-1.34.33c-.38.29-.61.65-.71 1.06a2.1 2.1 0 0 0-1.1-.56 1.78 1.78 0 0 0-.99.13l-2.64-2.64a1.88 1.88 0 0 0-2.65 0 1.86 1.86 0 0 0-.48.85 1.89 1.89 0 0 0-2.67-.01 1.87 1.87 0 0 0-.5.9c-.76-.75-2-.75-2.7-.04a1.88 1.88 0 0 0 0 2.66c-.3.12-.61.29-.87.55a1.88 1.88 0 0 0 0 2.66l.62.62a1.88 1.88 0 0 0-.9 3.16l5.01 5.02c1.6 1.6 3.52 2.64 5.4 2.96a7.16 7.16 0 0 0 1.18.1c1.03 0 2-.25 2.9-.7A5.9 5.9 0 0 0 23 23.24c3.34-3.34 3.08-6.93 1.74-9.17l-2.87-5.04z"></path></g></svg></div></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_sidebar--------------------------bookmark_sidebar-" rel="noopener"><svg height="25" viewBox="0 0 25 25" width="25"><path d="M19 6a2 2 0 0 0-2-2H8a2 2 0 0 0-2 2v14.66h.01c.01.1.05.2.12.28a.5.5 0 0 0 .7.03l5.67-4.12 5.66 4.13a.5.5 0 0 0 .71-.03.5.5 0 0 0 .12-.29H19V6zm-6.84 9.97L7 19.64V6a1 1 0 0 1 1-1h9a1 1 0 0 1 1 1v13.64l-5.16-3.67a.49.49 0 0 0-.68 0z" fill-rule="evenodd"></path></svg></a>,
#  <a class="mf mg by ax r iz mh a b cy" href="/tag/python">Python</a>,
#  <a class="mf mg by ax r iz mh a b cy" href="/tag/web-scraping">Web Scraping</a>,
#  <a class="mf mg by ax r iz mh a b cy" href="/tag/beautifulsoup">Beautifulsoup</a>,
#  <a class="mf mg by ax r iz mh a b cy" href="/tag/web-crawling">Web Crawling</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_actions_footer-----4dde18468f1f---------------------clap_footer-" rel="noopener"><div class="c mk fc n o ml gz mm mn mo mp mq mr ms mt mu mv mw mx my bs"><div class="bg lq lr ls lt lu mz lw o hm fc n p na u hd ds t ak ba lx bk nb"><svg height="33" viewBox="0 0 33 33" width="33"><path d="M28.86 17.34l-3.64-6.4c-.3-.43-.71-.73-1.16-.8a1.12 1.12 0 0 0-.9.21c-.62.5-.73 1.18-.32 2.06l1.22 2.6 1.4 2.45c2.23 4.09 1.51 8-2.15 11.66a9.6 9.6 0 0 1-.8.71 6.53 6.53 0 0 0 4.3-2.1c3.82-3.82 3.57-7.87 2.05-10.39zm-6.25 11.08c3.35-3.35 4-6.78 1.98-10.47L21.2 12c-.3-.43-.71-.72-1.16-.8a1.12 1.12 0 0 0-.9.22c-.62.49-.74 1.18-.32 2.06l1.72 3.63a.5.5 0 0 1-.81.57l-8.91-8.9a1.33 1.33 0 0 0-1.89 1.88l5.3 5.3a.5.5 0 0 1-.71.7l-5.3-5.3-1.49-1.49c-.5-.5-1.38-.5-1.88 0a1.34 1.34 0 0 0 0 1.89l1.49 1.5 5.3 5.28a.5.5 0 0 1-.36.86.5.5 0 0 1-.36-.15l-5.29-5.29a1.34 1.34 0 0 0-1.88 0 1.34 1.34 0 0 0 0 1.89l2.23 2.23L9.3 21.4a.5.5 0 0 1-.36.85.5.5 0 0 1-.35-.14l-3.32-3.33a1.33 1.33 0 0 0-1.89 0 1.32 1.32 0 0 0-.39.95c0 .35.14.69.4.94l6.39 6.4c3.53 3.53 8.86 5.3 12.82 1.35zM12.73 9.26l5.68 5.68-.49-1.04c-.52-1.1-.43-2.13.22-2.89l-3.3-3.3a1.34 1.34 0 0 0-1.88 0 1.33 1.33 0 0 0-.4.94c0 .22.07.42.17.61zm14.79 19.18a7.46 7.46 0 0 1-6.41 2.31 7.92 7.92 0 0 1-3.67.9c-3.05 0-6.12-1.63-8.36-3.88l-6.4-6.4A2.31 2.31 0 0 1 2 19.72a2.33 2.33 0 0 1 1.92-2.3l-.87-.87a2.34 2.34 0 0 1 0-3.3 2.33 2.33 0 0 1 1.24-.64l-.14-.14a2.34 2.34 0 0 1 0-3.3 2.39 2.39 0 0 1 3.3 0l.14.14a2.33 2.33 0 0 1 3.95-1.24l.09.09c.09-.42.29-.83.62-1.16a2.34 2.34 0 0 1 3.3 0l3.38 3.39a2.17 2.17 0 0 1 1.27-.17c.54.08 1.03.35 1.45.76.1-.55.41-1.03.9-1.42a2.12 2.12 0 0 1 1.67-.4 2.8 2.8 0 0 1 1.85 1.25l3.65 6.43c1.7 2.83 2.03 7.37-2.2 11.6zM13.22.48l-1.92.89 2.37 2.83-.45-3.72zm8.48.88L19.78.5l-.44 3.7 2.36-2.84zM16.5 3.3L15.48 0h2.04L16.5 3.3z" fill-rule="evenodd"></path></svg></div></div></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/twitter?source=post_actions_footer---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M22.05 7.54a4.47 4.47 0 0 0-3.3-1.46 4.53 4.53 0 0 0-4.53 4.53c0 .35.04.7.08 1.05A12.9 12.9 0 0 1 5 6.89a5.1 5.1 0 0 0-.65 2.26c.03 1.6.83 2.99 2.02 3.79a4.3 4.3 0 0 1-2.02-.57v.08a4.55 4.55 0 0 0 3.63 4.44c-.4.08-.8.13-1.21.16l-.81-.08a4.54 4.54 0 0 0 4.2 3.15 9.56 9.56 0 0 1-5.66 1.94l-1.05-.08c2 1.27 4.38 2.02 6.94 2.02 8.3 0 12.86-6.9 12.84-12.85.02-.24 0-.43 0-.65a8.68 8.68 0 0 0 2.26-2.34c-.82.38-1.7.62-2.6.72a4.37 4.37 0 0 0 1.95-2.51c-.84.53-1.81.9-2.83 1.13z"></path></svg></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/facebook?source=post_actions_footer---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M23.2 5H5.8a.8.8 0 0 0-.8.8V23.2c0 .44.35.8.8.8h9.3v-7.13h-2.38V13.9h2.38v-2.38c0-2.45 1.55-3.66 3.74-3.66 1.05 0 1.95.08 2.2.11v2.57h-1.5c-1.2 0-1.48.57-1.48 1.4v1.96h2.97l-.6 2.97h-2.37l.05 7.12h5.1a.8.8 0 0 0 .79-.8V5.8a.8.8 0 0 0-.8-.79"></path></svg></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_actions_footer--------------------------bookmark_sidebar-" rel="noopener"><svg height="25" viewBox="0 0 25 25" width="25"><path d="M19 6a2 2 0 0 0-2-2H8a2 2 0 0 0-2 2v14.66h.01c.01.1.05.2.12.28a.5.5 0 0 0 .7.03l5.67-4.12 5.66 4.13a.5.5 0 0 0 .71-.03.5.5 0 0 0 .12-.29H19V6zm-6.84 9.97L7 19.64V6a1 1 0 0 1 1-1h9a1 1 0 0 1 1 1v13.64l-5.16-3.67a.49.49 0 0 0-.68 0z" fill-rule="evenodd"></path></svg></a>,
#  <a href="/@yunhanh?source=follow_footer--------------------------follow_footer-" rel="noopener"><img alt="Hannah Huang" class="r fc cq nl" height="80" src="https://miro.medium.com/fit/c/160/160/1*Vy9pmdUSKQjWdPz79tfaOw@2x.jpeg" width="80"/></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="/@yunhanh?source=follow_footer--------------------------follow_footer-" rel="noopener">Hannah Huang</a>,
#  <a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer-b3c4a67e76b6-------------------------follow_footer-" rel="noopener">Follow</a>,
#  <a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer-b3c4a67e76b6-------------------------follow_footer-" rel="noopener">Follow</a>,
#  <a href="https://levelup.gitconnected.com/?source=follow_footer--------------------------follow_footer-" rel="noopener"><img alt="Level Up Coding" class="bt nl cq" height="80" src="https://miro.medium.com/fit/c/160/160/1*5D9oYBd58pyjMkV_5-zXXQ.jpeg" width="80"/></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://levelup.gitconnected.com/?source=follow_footer--------------------------follow_footer-" rel="noopener">Level Up Coding</a>,
#  <a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer--------------------------follow_footer-" rel="noopener">Follow</a>,
#  <a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer--------------------------follow_footer-" rel="noopener">Follow</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/p/4dde18468f1f/responses/show?source=follow_footer--------------------------follow_footer-" rel="noopener"><span class="nz oa lt"><div class="iy ob bt r kp cb"><span class="az">See responses (1)</span></div></span></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/about?autoplay=1&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener"><h4 class="pg ph pi as id at nu pj pk r">Discover <!-- -->Medium</h4></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi bl bm pe pf pn" href="https://medium.com/about?autoplay=1&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener">Watch</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/topics?source=post_page-----4dde18468f1f----------------------" rel="noopener"><h4 class="pg ph pi as id at nu pj pk r">Make <!-- -->Medium<!-- --> yours</h4></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi bl bm pe pf pn" href="https://medium.com/topics?source=post_page-----4dde18468f1f----------------------" rel="noopener">Explore</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/membership?source=post_page-----4dde18468f1f----------------------" rel="noopener"><h4 class="pg ph pi as id at nu pj pk r">Become a member</h4></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi bl bm pe pf pn" href="https://medium.com/membership?source=post_page-----4dde18468f1f----------------------" rel="noopener">Upgrade</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><svg class="ph" height="22" viewBox="0 0 111.5 22" width="112"><path d="M56.3 19.5c0 .4 0 .5.3.7l1.5 1.4v.1h-6.5V19c-.7 1.8-2.4 3-4.3 3-3.3 0-5.8-2.6-5.8-7.5 0-4.5 2.6-7.6 6.3-7.6 1.6-.1 3.1.8 3.8 2.4V3.2c0-.3-.1-.6-.3-.7l-1.4-1.4V1l6.5-.8v19.3zm-4.8-.8V9.5c-.5-.6-1.2-.9-1.9-.9-1.6 0-3.1 1.4-3.1 5.7 0 4 1.3 5.4 3 5.4.8.1 1.6-.3 2-1zm9.1 3.1V9.4c0-.3-.1-.6-.3-.7l-1.4-1.5v-.1h6.5v12.5c0 .4 0 .5.3.7l1.4 1.4v.1h-6.5zm-.2-19.2C60.4 1.2 61.5 0 63 0c1.4 0 2.6 1.2 2.6 2.6S64.4 5.3 63 5.3a2.6 2.6 0 0 1-2.6-2.7zm22.5 16.9c0 .4 0 .5.3.7l1.5 1.4v.1h-6.5v-3.2c-.6 2-2.4 3.4-4.5 3.4-2.9 0-4.4-2.1-4.4-6.2 0-1.9 0-4.1.1-6.5 0-.3-.1-.5-.3-.7L67.7 7v.1H74v8c0 2.6.4 4.4 2 4.4.9-.1 1.7-.6 2.1-1.3V9.5c0-.3-.1-.6-.3-.7l-1.4-1.5v-.2h6.5v12.4zm22 2.3c0-.5.1-6.5.1-7.9 0-2.6-.4-4.5-2.2-4.5-.9 0-1.8.5-2.3 1.3.2.8.3 1.7.3 2.5 0 1.8-.1 4.2-.1 6.5 0 .3.1.5.3.7l1.5 1.4v.1H96c0-.4.1-6.5.1-7.9 0-2.7-.4-4.5-2.2-4.5-.9 0-1.7.5-2.2 1.3v9c0 .4 0 .5.3.7l1.4 1.4v.1h-6.5V9.5c0-.3-.1-.6-.3-.7l-1.4-1.5v-.2h6.5v3.1a4.6 4.6 0 0 1 4.6-3.4c2.2 0 3.6 1.2 4.2 3.5.7-2.1 2.7-3.6 4.9-3.5 2.9 0 4.5 2.2 4.5 6.2 0 1.9-.1 4.2-.1 6.5-.1.3.1.6.3.7l1.4 1.4v.1h-6.6zm-81.4-2l1.9 1.9v.1h-9.8v-.1l2-1.9c.2-.2.3-.4.3-.7V7.3c0-.5 0-1.2.1-1.8L11.4 22h-.1L4.5 6.8c-.1-.4-.2-.4-.3-.6v10c-.1.7 0 1.3.3 1.9l2.7 3.6v.1H0v-.1L2.7 18c.3-.6.4-1.3.3-1.9v-11c0-.5-.1-1.1-.5-1.5L.7 1.1V1h7l5.8 12.9L18.6 1h6.8v.1l-1.9 2.2c-.2.2-.3.5-.3.7v15.2c0 .2.1.5.3.6zm7.6-5.9c0 3.8 1.9 5.3 4.2 5.3 1.9.1 3.6-1 4.4-2.7h.1c-.8 3.7-3.1 5.5-6.5 5.5-3.7 0-7.2-2.2-7.2-7.4 0-5.5 3.5-7.6 7.3-7.6 3.1 0 6.4 1.5 6.4 6.2v.8h-8.7zm0-.8h4.3v-.8c0-3.9-.8-4.9-2-4.9-1.4.1-2.3 1.6-2.3 5.7z"></path></svg></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi fo bl bm pe pf" href="https://medium.com/about?autoplay=1&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener">About</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi fo bl bm pe pf" href="https://help.medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener">Help</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi fo bl bm pe pf" href="https://medium.com/policy/9db0094a1e0f?source=post_page-----4dde18468f1f----------------------" rel="noopener">Legal</a>]

# %%
soup.find_all('h1')
# Out:
# [<h1 class="eg b eh es ej et el eu en ev ep ew ef">Quick Web Scraping with Python and Beautiful Soup</h1>,
#  <h1 class="ib ic ef at as id eh ie ej if ig ih ii ij ik il im" id="8b1a">Beautiful Soup</h1>,
#  <h1 class="ib ic ef at as id eh ie ej if ig ih ii ij ik il im" id="9a96">Environment Set Up</h1>,
#  <h1 class="ib ic ef at as id eh ie ej if ig ih ii ij ik il im" id="7793"><strong class="bf">Beautiful Soup Object</strong></h1>,
#  <h1 class="ib ic ef at as id eh ie ej if ig ih ii ij ik il im" id="10fb">Obtaining data by using BeautifulSoup</h1>]

# %%
soup.find('h1')
# Out:
# <h1 class="eg b eh es ej et el eu en ev ep ew ef">Quick Web Scraping with Python and Beautiful Soup</h1>

# %%
lis=[]
for i in soup.find_all('a'):
    lis.append(i)

# %%
len(lis)
# Out:
# 47

# %%
lis
# Out:
# [<a aria-label="Homepage" href="https://medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><svg class="q" height="35" viewBox="5 5 35 35" width="35"><path d="M5 40V5h35v35H5zm8.56-12.63c0 .56-.03.69-.32 1.03L10.8 31.4v.4h6.97v-.4L15.3 28.4c-.29-.34-.34-.5-.34-1.03v-8.95l6.13 13.36h.71l5.26-13.36v10.64c0 .3 0 .35-.19.53l-1.85 1.8v.4h9.2v-.4l-1.83-1.8c-.18-.18-.2-.24-.2-.53V15.94c0-.3.02-.35.2-.53l1.82-1.8v-.4h-6.47l-4.62 11.55-5.2-11.54h-6.8v.4l2.15 2.63c.24.3.29.37.29.77v10.35z"></path></svg></a>,
#  <a class="az ba bb bc bd be bf bg bh bi bj bk bl bm bn bo" href="https://medium.com/m/signin?operation=login&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_page-----4dde18468f1f---------------------nav_reg-" rel="noopener">Sign in</a>,
#  <a class="bp bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_page-----4dde18468f1f---------------------nav_reg-" rel="noopener">Get started</a>,
#  <a href="https://levelup.gitconnected.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><div class="cf cg r"><img alt="Level Up Coding" class="" height="36" src="https://miro.medium.com/max/490/1*9EJ1XEKLx0P1-ey1Fmc6vg.png" width="245"/></div></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="/how-to-get-published-on-gitconnected-dac547ef556b?source=post_page-----4dde18468f1f----------------------" rel="noopener">WRITE FOR US</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="/the-2020-web-developer-roadmap-76503ddfb327?source=post_page-----4dde18468f1f----------------------" rel="noopener">Web Dev Roadmap 2020</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="https://gitconnected.com/portfolio-api?utm_source=medium&amp;utm_medium=nav&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener">Your Dev Portfolio API →</a>,
#  <a href="/@yunhanh?source=post_page-----4dde18468f1f----------------------" rel="noopener"><img alt="Hannah Huang" class="r fc fd fe" height="48" src="https://miro.medium.com/fit/c/96/96/1*Vy9pmdUSKQjWdPz79tfaOw@2x.jpeg" width="48"/></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi fo bl bm fp fq" href="/@yunhanh?source=post_page-----4dde18468f1f----------------------" rel="noopener">Hannah Huang</a>,
#  <a class="fs ef q bq ft fu fv fw bi fp fx fy fz ga gb gc bt as b at gd cy aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=-b3c4a67e76b6-------------------------follow_byline-" rel="noopener">Follow</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi fo bl bm fp fq" href="/quick-web-scraping-with-python-beautiful-soup-4dde18468f1f?source=post_page-----4dde18468f1f----------------------" rel="noopener">Jun 15, 2019</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/twitter?source=post_actions_header---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M22.05 7.54a4.47 4.47 0 0 0-3.3-1.46 4.53 4.53 0 0 0-4.53 4.53c0 .35.04.7.08 1.05A12.9 12.9 0 0 1 5 6.89a5.1 5.1 0 0 0-.65 2.26c.03 1.6.83 2.99 2.02 3.79a4.3 4.3 0 0 1-2.02-.57v.08a4.55 4.55 0 0 0 3.63 4.44c-.4.08-.8.13-1.21.16l-.81-.08a4.54 4.54 0 0 0 4.2 3.15 9.56 9.56 0 0 1-5.66 1.94l-1.05-.08c2 1.27 4.38 2.02 6.94 2.02 8.3 0 12.86-6.9 12.84-12.85.02-.24 0-.43 0-.65a8.68 8.68 0 0 0 2.26-2.34c-.82.38-1.7.62-2.6.72a4.37 4.37 0 0 0 1.95-2.51c-.84.53-1.81.9-2.83 1.13z"></path></svg></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/facebook?source=post_actions_header---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M23.2 5H5.8a.8.8 0 0 0-.8.8V23.2c0 .44.35.8.8.8h9.3v-7.13h-2.38V13.9h2.38v-2.38c0-2.45 1.55-3.66 3.74-3.66 1.05 0 1.95.08 2.2.11v2.57h-1.5c-1.2 0-1.48.57-1.48 1.4v1.96h2.97l-.6 2.97h-2.37l.05 7.12h5.1a.8.8 0 0 0 .79-.8V5.8a.8.8 0 0 0-.8-.79"></path></svg></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_actions_header--------------------------bookmark_sidebar-" rel="noopener"><svg height="25" viewBox="0 0 25 25" width="25"><path d="M19 6a2 2 0 0 0-2-2H8a2 2 0 0 0-2 2v14.66h.01c.01.1.05.2.12.28a.5.5 0 0 0 .7.03l5.67-4.12 5.66 4.13a.5.5 0 0 0 .71-.03.5.5 0 0 0 .12-.29H19V6zm-6.84 9.97L7 19.64V6a1 1 0 0 1 1-1h9a1 1 0 0 1 1 1v13.64l-5.16-3.67a.49.49 0 0 0-.68 0z" fill-rule="evenodd"></path></svg></a>,
#  <a class="dc by kd ke kf kg" href="http://www.bu.edu/president/boston-university-facts-stats/" rel="noopener" target="_blank">website</a>,
#  <a class="dc by kd ke kf kg" href="http://www.bu.edu/president/boston-university-facts-stats/" rel="noopener" target="_blank">http://www.bu.edu/president/boston-university-facts-stats/</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://levelup.gitconnected.com/?source=post_sidebar--------------------------post_sidebar-" rel="noopener"><h2 class="as id lg au ef">Level Up Coding</h2></a>,
#  <a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_sidebar--------------------------follow_sidebar-" rel="noopener">Follow</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_sidebar-----4dde18468f1f---------------------clap_sidebar-" rel="noopener"><div class="bg lq lr ls lt lu lv lw ba lx bk"><svg height="29" width="29"><g fill-rule="evenodd"><path d="M13.74 1l.76 2.97.76-2.97zM16.82 4.78l1.84-2.56-1.43-.47zM10.38 2.22l1.84 2.56-.41-3.03zM22.38 22.62a5.11 5.11 0 0 1-3.16 1.61l.49-.45c2.88-2.89 3.45-5.98 1.69-9.21l-1.1-1.94-.96-2.02c-.31-.67-.23-1.18.25-1.55a.84.84 0 0 1 .66-.16c.34.05.66.28.88.6l2.85 5.02c1.18 1.97 1.38 5.12-1.6 8.1M9.1 22.1l-5.02-5.02a1 1 0 0 1 .7-1.7 1 1 0 0 1 .72.3l2.6 2.6a.44.44 0 0 0 .63-.62L6.1 15.04l-1.75-1.75a1 1 0 1 1 1.41-1.41l4.15 4.15a.44.44 0 0 0 .63 0 .44.44 0 0 0 0-.62L6.4 11.26l-1.18-1.18a1 1 0 0 1 0-1.4 1.02 1.02 0 0 1 1.41 0l1.18 1.16L11.96 14a.44.44 0 0 0 .62 0 .44.44 0 0 0 0-.63L8.43 9.22a.99.99 0 0 1-.3-.7.99.99 0 0 1 .3-.7 1 1 0 0 1 1.41 0l7 6.98a.44.44 0 0 0 .7-.5l-1.35-2.85c-.31-.68-.23-1.19.25-1.56a.85.85 0 0 1 .66-.16c.34.06.66.28.88.6L20.63 15c1.57 2.88 1.07 5.54-1.55 8.16a5.62 5.62 0 0 1-5.06 1.65 9.35 9.35 0 0 1-4.93-2.72zM13 6.98l2.56 2.56c-.5.6-.56 1.41-.15 2.28l.26.56-4.25-4.25a.98.98 0 0 1-.12-.45 1 1 0 0 1 .29-.7 1.02 1.02 0 0 1 1.41 0zm8.89 2.06c-.38-.56-.9-.92-1.49-1.01a1.74 1.74 0 0 0-1.34.33c-.38.29-.61.65-.71 1.06a2.1 2.1 0 0 0-1.1-.56 1.78 1.78 0 0 0-.99.13l-2.64-2.64a1.88 1.88 0 0 0-2.65 0 1.86 1.86 0 0 0-.48.85 1.89 1.89 0 0 0-2.67-.01 1.87 1.87 0 0 0-.5.9c-.76-.75-2-.75-2.7-.04a1.88 1.88 0 0 0 0 2.66c-.3.12-.61.29-.87.55a1.88 1.88 0 0 0 0 2.66l.62.62a1.88 1.88 0 0 0-.9 3.16l5.01 5.02c1.6 1.6 3.52 2.64 5.4 2.96a7.16 7.16 0 0 0 1.18.1c1.03 0 2-.25 2.9-.7A5.9 5.9 0 0 0 23 23.24c3.34-3.34 3.08-6.93 1.74-9.17l-2.87-5.04z"></path></g></svg></div></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_sidebar--------------------------bookmark_sidebar-" rel="noopener"><svg height="25" viewBox="0 0 25 25" width="25"><path d="M19 6a2 2 0 0 0-2-2H8a2 2 0 0 0-2 2v14.66h.01c.01.1.05.2.12.28a.5.5 0 0 0 .7.03l5.67-4.12 5.66 4.13a.5.5 0 0 0 .71-.03.5.5 0 0 0 .12-.29H19V6zm-6.84 9.97L7 19.64V6a1 1 0 0 1 1-1h9a1 1 0 0 1 1 1v13.64l-5.16-3.67a.49.49 0 0 0-.68 0z" fill-rule="evenodd"></path></svg></a>,
#  <a class="mf mg by ax r iz mh a b cy" href="/tag/python">Python</a>,
#  <a class="mf mg by ax r iz mh a b cy" href="/tag/web-scraping">Web Scraping</a>,
#  <a class="mf mg by ax r iz mh a b cy" href="/tag/beautifulsoup">Beautifulsoup</a>,
#  <a class="mf mg by ax r iz mh a b cy" href="/tag/web-crawling">Web Crawling</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_actions_footer-----4dde18468f1f---------------------clap_footer-" rel="noopener"><div class="c mk fc n o ml gz mm mn mo mp mq mr ms mt mu mv mw mx my bs"><div class="bg lq lr ls lt lu mz lw o hm fc n p na u hd ds t ak ba lx bk nb"><svg height="33" viewBox="0 0 33 33" width="33"><path d="M28.86 17.34l-3.64-6.4c-.3-.43-.71-.73-1.16-.8a1.12 1.12 0 0 0-.9.21c-.62.5-.73 1.18-.32 2.06l1.22 2.6 1.4 2.45c2.23 4.09 1.51 8-2.15 11.66a9.6 9.6 0 0 1-.8.71 6.53 6.53 0 0 0 4.3-2.1c3.82-3.82 3.57-7.87 2.05-10.39zm-6.25 11.08c3.35-3.35 4-6.78 1.98-10.47L21.2 12c-.3-.43-.71-.72-1.16-.8a1.12 1.12 0 0 0-.9.22c-.62.49-.74 1.18-.32 2.06l1.72 3.63a.5.5 0 0 1-.81.57l-8.91-8.9a1.33 1.33 0 0 0-1.89 1.88l5.3 5.3a.5.5 0 0 1-.71.7l-5.3-5.3-1.49-1.49c-.5-.5-1.38-.5-1.88 0a1.34 1.34 0 0 0 0 1.89l1.49 1.5 5.3 5.28a.5.5 0 0 1-.36.86.5.5 0 0 1-.36-.15l-5.29-5.29a1.34 1.34 0 0 0-1.88 0 1.34 1.34 0 0 0 0 1.89l2.23 2.23L9.3 21.4a.5.5 0 0 1-.36.85.5.5 0 0 1-.35-.14l-3.32-3.33a1.33 1.33 0 0 0-1.89 0 1.32 1.32 0 0 0-.39.95c0 .35.14.69.4.94l6.39 6.4c3.53 3.53 8.86 5.3 12.82 1.35zM12.73 9.26l5.68 5.68-.49-1.04c-.52-1.1-.43-2.13.22-2.89l-3.3-3.3a1.34 1.34 0 0 0-1.88 0 1.33 1.33 0 0 0-.4.94c0 .22.07.42.17.61zm14.79 19.18a7.46 7.46 0 0 1-6.41 2.31 7.92 7.92 0 0 1-3.67.9c-3.05 0-6.12-1.63-8.36-3.88l-6.4-6.4A2.31 2.31 0 0 1 2 19.72a2.33 2.33 0 0 1 1.92-2.3l-.87-.87a2.34 2.34 0 0 1 0-3.3 2.33 2.33 0 0 1 1.24-.64l-.14-.14a2.34 2.34 0 0 1 0-3.3 2.39 2.39 0 0 1 3.3 0l.14.14a2.33 2.33 0 0 1 3.95-1.24l.09.09c.09-.42.29-.83.62-1.16a2.34 2.34 0 0 1 3.3 0l3.38 3.39a2.17 2.17 0 0 1 1.27-.17c.54.08 1.03.35 1.45.76.1-.55.41-1.03.9-1.42a2.12 2.12 0 0 1 1.67-.4 2.8 2.8 0 0 1 1.85 1.25l3.65 6.43c1.7 2.83 2.03 7.37-2.2 11.6zM13.22.48l-1.92.89 2.37 2.83-.45-3.72zm8.48.88L19.78.5l-.44 3.7 2.36-2.84zM16.5 3.3L15.48 0h2.04L16.5 3.3z" fill-rule="evenodd"></path></svg></div></div></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/twitter?source=post_actions_footer---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M22.05 7.54a4.47 4.47 0 0 0-3.3-1.46 4.53 4.53 0 0 0-4.53 4.53c0 .35.04.7.08 1.05A12.9 12.9 0 0 1 5 6.89a5.1 5.1 0 0 0-.65 2.26c.03 1.6.83 2.99 2.02 3.79a4.3 4.3 0 0 1-2.02-.57v.08a4.55 4.55 0 0 0 3.63 4.44c-.4.08-.8.13-1.21.16l-.81-.08a4.54 4.54 0 0 0 4.2 3.15 9.56 9.56 0 0 1-5.66 1.94l-1.05-.08c2 1.27 4.38 2.02 6.94 2.02 8.3 0 12.86-6.9 12.84-12.85.02-.24 0-.43 0-.65a8.68 8.68 0 0 0 2.26-2.34c-.82.38-1.7.62-2.6.72a4.37 4.37 0 0 0 1.95-2.51c-.84.53-1.81.9-2.83 1.13z"></path></svg></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/facebook?source=post_actions_footer---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M23.2 5H5.8a.8.8 0 0 0-.8.8V23.2c0 .44.35.8.8.8h9.3v-7.13h-2.38V13.9h2.38v-2.38c0-2.45 1.55-3.66 3.74-3.66 1.05 0 1.95.08 2.2.11v2.57h-1.5c-1.2 0-1.48.57-1.48 1.4v1.96h2.97l-.6 2.97h-2.37l.05 7.12h5.1a.8.8 0 0 0 .79-.8V5.8a.8.8 0 0 0-.8-.79"></path></svg></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_actions_footer--------------------------bookmark_sidebar-" rel="noopener"><svg height="25" viewBox="0 0 25 25" width="25"><path d="M19 6a2 2 0 0 0-2-2H8a2 2 0 0 0-2 2v14.66h.01c.01.1.05.2.12.28a.5.5 0 0 0 .7.03l5.67-4.12 5.66 4.13a.5.5 0 0 0 .71-.03.5.5 0 0 0 .12-.29H19V6zm-6.84 9.97L7 19.64V6a1 1 0 0 1 1-1h9a1 1 0 0 1 1 1v13.64l-5.16-3.67a.49.49 0 0 0-.68 0z" fill-rule="evenodd"></path></svg></a>,
#  <a href="/@yunhanh?source=follow_footer--------------------------follow_footer-" rel="noopener"><img alt="Hannah Huang" class="r fc cq nl" height="80" src="https://miro.medium.com/fit/c/160/160/1*Vy9pmdUSKQjWdPz79tfaOw@2x.jpeg" width="80"/></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="/@yunhanh?source=follow_footer--------------------------follow_footer-" rel="noopener">Hannah Huang</a>,
#  <a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer-b3c4a67e76b6-------------------------follow_footer-" rel="noopener">Follow</a>,
#  <a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer-b3c4a67e76b6-------------------------follow_footer-" rel="noopener">Follow</a>,
#  <a href="https://levelup.gitconnected.com/?source=follow_footer--------------------------follow_footer-" rel="noopener"><img alt="Level Up Coding" class="bt nl cq" height="80" src="https://miro.medium.com/fit/c/160/160/1*5D9oYBd58pyjMkV_5-zXXQ.jpeg" width="80"/></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://levelup.gitconnected.com/?source=follow_footer--------------------------follow_footer-" rel="noopener">Level Up Coding</a>,
#  <a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer--------------------------follow_footer-" rel="noopener">Follow</a>,
#  <a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer--------------------------follow_footer-" rel="noopener">Follow</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/p/4dde18468f1f/responses/show?source=follow_footer--------------------------follow_footer-" rel="noopener"><span class="nz oa lt"><div class="iy ob bt r kp cb"><span class="az">See responses (1)</span></div></span></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/about?autoplay=1&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener"><h4 class="pg ph pi as id at nu pj pk r">Discover <!-- -->Medium</h4></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi bl bm pe pf pn" href="https://medium.com/about?autoplay=1&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener">Watch</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/topics?source=post_page-----4dde18468f1f----------------------" rel="noopener"><h4 class="pg ph pi as id at nu pj pk r">Make <!-- -->Medium<!-- --> yours</h4></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi bl bm pe pf pn" href="https://medium.com/topics?source=post_page-----4dde18468f1f----------------------" rel="noopener">Explore</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/membership?source=post_page-----4dde18468f1f----------------------" rel="noopener"><h4 class="pg ph pi as id at nu pj pk r">Become a member</h4></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi bl bm pe pf pn" href="https://medium.com/membership?source=post_page-----4dde18468f1f----------------------" rel="noopener">Upgrade</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><svg class="ph" height="22" viewBox="0 0 111.5 22" width="112"><path d="M56.3 19.5c0 .4 0 .5.3.7l1.5 1.4v.1h-6.5V19c-.7 1.8-2.4 3-4.3 3-3.3 0-5.8-2.6-5.8-7.5 0-4.5 2.6-7.6 6.3-7.6 1.6-.1 3.1.8 3.8 2.4V3.2c0-.3-.1-.6-.3-.7l-1.4-1.4V1l6.5-.8v19.3zm-4.8-.8V9.5c-.5-.6-1.2-.9-1.9-.9-1.6 0-3.1 1.4-3.1 5.7 0 4 1.3 5.4 3 5.4.8.1 1.6-.3 2-1zm9.1 3.1V9.4c0-.3-.1-.6-.3-.7l-1.4-1.5v-.1h6.5v12.5c0 .4 0 .5.3.7l1.4 1.4v.1h-6.5zm-.2-19.2C60.4 1.2 61.5 0 63 0c1.4 0 2.6 1.2 2.6 2.6S64.4 5.3 63 5.3a2.6 2.6 0 0 1-2.6-2.7zm22.5 16.9c0 .4 0 .5.3.7l1.5 1.4v.1h-6.5v-3.2c-.6 2-2.4 3.4-4.5 3.4-2.9 0-4.4-2.1-4.4-6.2 0-1.9 0-4.1.1-6.5 0-.3-.1-.5-.3-.7L67.7 7v.1H74v8c0 2.6.4 4.4 2 4.4.9-.1 1.7-.6 2.1-1.3V9.5c0-.3-.1-.6-.3-.7l-1.4-1.5v-.2h6.5v12.4zm22 2.3c0-.5.1-6.5.1-7.9 0-2.6-.4-4.5-2.2-4.5-.9 0-1.8.5-2.3 1.3.2.8.3 1.7.3 2.5 0 1.8-.1 4.2-.1 6.5 0 .3.1.5.3.7l1.5 1.4v.1H96c0-.4.1-6.5.1-7.9 0-2.7-.4-4.5-2.2-4.5-.9 0-1.7.5-2.2 1.3v9c0 .4 0 .5.3.7l1.4 1.4v.1h-6.5V9.5c0-.3-.1-.6-.3-.7l-1.4-1.5v-.2h6.5v3.1a4.6 4.6 0 0 1 4.6-3.4c2.2 0 3.6 1.2 4.2 3.5.7-2.1 2.7-3.6 4.9-3.5 2.9 0 4.5 2.2 4.5 6.2 0 1.9-.1 4.2-.1 6.5-.1.3.1.6.3.7l1.4 1.4v.1h-6.6zm-81.4-2l1.9 1.9v.1h-9.8v-.1l2-1.9c.2-.2.3-.4.3-.7V7.3c0-.5 0-1.2.1-1.8L11.4 22h-.1L4.5 6.8c-.1-.4-.2-.4-.3-.6v10c-.1.7 0 1.3.3 1.9l2.7 3.6v.1H0v-.1L2.7 18c.3-.6.4-1.3.3-1.9v-11c0-.5-.1-1.1-.5-1.5L.7 1.1V1h7l5.8 12.9L18.6 1h6.8v.1l-1.9 2.2c-.2.2-.3.5-.3.7v15.2c0 .2.1.5.3.6zm7.6-5.9c0 3.8 1.9 5.3 4.2 5.3 1.9.1 3.6-1 4.4-2.7h.1c-.8 3.7-3.1 5.5-6.5 5.5-3.7 0-7.2-2.2-7.2-7.4 0-5.5 3.5-7.6 7.3-7.6 3.1 0 6.4 1.5 6.4 6.2v.8h-8.7zm0-.8h4.3v-.8c0-3.9-.8-4.9-2-4.9-1.4.1-2.3 1.6-2.3 5.7z"></path></svg></a>,
#  <a class="dc dd bb bc bd be bf bg bh bi fo bl bm pe pf" href="https://medium.com/about?autoplay=1&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener">About</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi fo bl bm pe pf" href="https://help.medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener">Help</a>,
#  <a class="dc dd bb bc bd be bf bg bh bi fo bl bm pe pf" href="https://medium.com/policy/9db0094a1e0f?source=post_page-----4dde18468f1f----------------------" rel="noopener">Legal</a>]

# %%
lis[0
   ]
# Out:
# <a aria-label="Homepage" href="https://medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><svg class="q" height="35" viewBox="5 5 35 35" width="35"><path d="M5 40V5h35v35H5zm8.56-12.63c0 .56-.03.69-.32 1.03L10.8 31.4v.4h6.97v-.4L15.3 28.4c-.29-.34-.34-.5-.34-1.03v-8.95l6.13 13.36h.71l5.26-13.36v10.64c0 .3 0 .35-.19.53l-1.85 1.8v.4h9.2v-.4l-1.83-1.8c-.18-.18-.2-.24-.2-.53V15.94c0-.3.02-.35.2-.53l1.82-1.8v-.4h-6.47l-4.62 11.55-5.2-11.54h-6.8v.4l2.15 2.63c.24.3.29.37.29.77v10.35z"></path></svg></a>

# %%
lis1 = []
for i in soup.find_all('a'):
    lis1.append([i])

# %%
lis1
# Out:
# [[<a aria-label="Homepage" href="https://medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><svg class="q" height="35" viewBox="5 5 35 35" width="35"><path d="M5 40V5h35v35H5zm8.56-12.63c0 .56-.03.69-.32 1.03L10.8 31.4v.4h6.97v-.4L15.3 28.4c-.29-.34-.34-.5-.34-1.03v-8.95l6.13 13.36h.71l5.26-13.36v10.64c0 .3 0 .35-.19.53l-1.85 1.8v.4h9.2v-.4l-1.83-1.8c-.18-.18-.2-.24-.2-.53V15.94c0-.3.02-.35.2-.53l1.82-1.8v-.4h-6.47l-4.62 11.55-5.2-11.54h-6.8v.4l2.15 2.63c.24.3.29.37.29.77v10.35z"></path></svg></a>],
#  [<a class="az ba bb bc bd be bf bg bh bi bj bk bl bm bn bo" href="https://medium.com/m/signin?operation=login&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_page-----4dde18468f1f---------------------nav_reg-" rel="noopener">Sign in</a>],
#  [<a class="bp bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_page-----4dde18468f1f---------------------nav_reg-" rel="noopener">Get started</a>],
#  [<a href="https://levelup.gitconnected.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><div class="cf cg r"><img alt="Level Up Coding" class="" height="36" src="https://miro.medium.com/max/490/1*9EJ1XEKLx0P1-ey1Fmc6vg.png" width="245"/></div></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="/how-to-get-published-on-gitconnected-dac547ef556b?source=post_page-----4dde18468f1f----------------------" rel="noopener">WRITE FOR US</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="/the-2020-web-developer-roadmap-76503ddfb327?source=post_page-----4dde18468f1f----------------------" rel="noopener">Web Dev Roadmap 2020</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi de df bl bm dg dh" href="https://gitconnected.com/portfolio-api?utm_source=medium&amp;utm_medium=nav&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener">Your Dev Portfolio API →</a>],
#  [<a href="/@yunhanh?source=post_page-----4dde18468f1f----------------------" rel="noopener"><img alt="Hannah Huang" class="r fc fd fe" height="48" src="https://miro.medium.com/fit/c/96/96/1*Vy9pmdUSKQjWdPz79tfaOw@2x.jpeg" width="48"/></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi fo bl bm fp fq" href="/@yunhanh?source=post_page-----4dde18468f1f----------------------" rel="noopener">Hannah Huang</a>],
#  [<a class="fs ef q bq ft fu fv fw bi fp fx fy fz ga gb gc bt as b at gd cy aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=-b3c4a67e76b6-------------------------follow_byline-" rel="noopener">Follow</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi fo bl bm fp fq" href="/quick-web-scraping-with-python-beautiful-soup-4dde18468f1f?source=post_page-----4dde18468f1f----------------------" rel="noopener">Jun 15, 2019</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/twitter?source=post_actions_header---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M22.05 7.54a4.47 4.47 0 0 0-3.3-1.46 4.53 4.53 0 0 0-4.53 4.53c0 .35.04.7.08 1.05A12.9 12.9 0 0 1 5 6.89a5.1 5.1 0 0 0-.65 2.26c.03 1.6.83 2.99 2.02 3.79a4.3 4.3 0 0 1-2.02-.57v.08a4.55 4.55 0 0 0 3.63 4.44c-.4.08-.8.13-1.21.16l-.81-.08a4.54 4.54 0 0 0 4.2 3.15 9.56 9.56 0 0 1-5.66 1.94l-1.05-.08c2 1.27 4.38 2.02 6.94 2.02 8.3 0 12.86-6.9 12.84-12.85.02-.24 0-.43 0-.65a8.68 8.68 0 0 0 2.26-2.34c-.82.38-1.7.62-2.6.72a4.37 4.37 0 0 0 1.95-2.51c-.84.53-1.81.9-2.83 1.13z"></path></svg></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/facebook?source=post_actions_header---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M23.2 5H5.8a.8.8 0 0 0-.8.8V23.2c0 .44.35.8.8.8h9.3v-7.13h-2.38V13.9h2.38v-2.38c0-2.45 1.55-3.66 3.74-3.66 1.05 0 1.95.08 2.2.11v2.57h-1.5c-1.2 0-1.48.57-1.48 1.4v1.96h2.97l-.6 2.97h-2.37l.05 7.12h5.1a.8.8 0 0 0 .79-.8V5.8a.8.8 0 0 0-.8-.79"></path></svg></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_actions_header--------------------------bookmark_sidebar-" rel="noopener"><svg height="25" viewBox="0 0 25 25" width="25"><path d="M19 6a2 2 0 0 0-2-2H8a2 2 0 0 0-2 2v14.66h.01c.01.1.05.2.12.28a.5.5 0 0 0 .7.03l5.67-4.12 5.66 4.13a.5.5 0 0 0 .71-.03.5.5 0 0 0 .12-.29H19V6zm-6.84 9.97L7 19.64V6a1 1 0 0 1 1-1h9a1 1 0 0 1 1 1v13.64l-5.16-3.67a.49.49 0 0 0-.68 0z" fill-rule="evenodd"></path></svg></a>],
#  [<a class="dc by kd ke kf kg" href="http://www.bu.edu/president/boston-university-facts-stats/" rel="noopener" target="_blank">website</a>],
#  [<a class="dc by kd ke kf kg" href="http://www.bu.edu/president/boston-university-facts-stats/" rel="noopener" target="_blank">http://www.bu.edu/president/boston-university-facts-stats/</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://levelup.gitconnected.com/?source=post_sidebar--------------------------post_sidebar-" rel="noopener"><h2 class="as id lg au ef">Level Up Coding</h2></a>],
#  [<a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_sidebar--------------------------follow_sidebar-" rel="noopener">Follow</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_sidebar-----4dde18468f1f---------------------clap_sidebar-" rel="noopener"><div class="bg lq lr ls lt lu lv lw ba lx bk"><svg height="29" width="29"><g fill-rule="evenodd"><path d="M13.74 1l.76 2.97.76-2.97zM16.82 4.78l1.84-2.56-1.43-.47zM10.38 2.22l1.84 2.56-.41-3.03zM22.38 22.62a5.11 5.11 0 0 1-3.16 1.61l.49-.45c2.88-2.89 3.45-5.98 1.69-9.21l-1.1-1.94-.96-2.02c-.31-.67-.23-1.18.25-1.55a.84.84 0 0 1 .66-.16c.34.05.66.28.88.6l2.85 5.02c1.18 1.97 1.38 5.12-1.6 8.1M9.1 22.1l-5.02-5.02a1 1 0 0 1 .7-1.7 1 1 0 0 1 .72.3l2.6 2.6a.44.44 0 0 0 .63-.62L6.1 15.04l-1.75-1.75a1 1 0 1 1 1.41-1.41l4.15 4.15a.44.44 0 0 0 .63 0 .44.44 0 0 0 0-.62L6.4 11.26l-1.18-1.18a1 1 0 0 1 0-1.4 1.02 1.02 0 0 1 1.41 0l1.18 1.16L11.96 14a.44.44 0 0 0 .62 0 .44.44 0 0 0 0-.63L8.43 9.22a.99.99 0 0 1-.3-.7.99.99 0 0 1 .3-.7 1 1 0 0 1 1.41 0l7 6.98a.44.44 0 0 0 .7-.5l-1.35-2.85c-.31-.68-.23-1.19.25-1.56a.85.85 0 0 1 .66-.16c.34.06.66.28.88.6L20.63 15c1.57 2.88 1.07 5.54-1.55 8.16a5.62 5.62 0 0 1-5.06 1.65 9.35 9.35 0 0 1-4.93-2.72zM13 6.98l2.56 2.56c-.5.6-.56 1.41-.15 2.28l.26.56-4.25-4.25a.98.98 0 0 1-.12-.45 1 1 0 0 1 .29-.7 1.02 1.02 0 0 1 1.41 0zm8.89 2.06c-.38-.56-.9-.92-1.49-1.01a1.74 1.74 0 0 0-1.34.33c-.38.29-.61.65-.71 1.06a2.1 2.1 0 0 0-1.1-.56 1.78 1.78 0 0 0-.99.13l-2.64-2.64a1.88 1.88 0 0 0-2.65 0 1.86 1.86 0 0 0-.48.85 1.89 1.89 0 0 0-2.67-.01 1.87 1.87 0 0 0-.5.9c-.76-.75-2-.75-2.7-.04a1.88 1.88 0 0 0 0 2.66c-.3.12-.61.29-.87.55a1.88 1.88 0 0 0 0 2.66l.62.62a1.88 1.88 0 0 0-.9 3.16l5.01 5.02c1.6 1.6 3.52 2.64 5.4 2.96a7.16 7.16 0 0 0 1.18.1c1.03 0 2-.25 2.9-.7A5.9 5.9 0 0 0 23 23.24c3.34-3.34 3.08-6.93 1.74-9.17l-2.87-5.04z"></path></g></svg></div></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_sidebar--------------------------bookmark_sidebar-" rel="noopener"><svg height="25" viewBox="0 0 25 25" width="25"><path d="M19 6a2 2 0 0 0-2-2H8a2 2 0 0 0-2 2v14.66h.01c.01.1.05.2.12.28a.5.5 0 0 0 .7.03l5.67-4.12 5.66 4.13a.5.5 0 0 0 .71-.03.5.5 0 0 0 .12-.29H19V6zm-6.84 9.97L7 19.64V6a1 1 0 0 1 1-1h9a1 1 0 0 1 1 1v13.64l-5.16-3.67a.49.49 0 0 0-.68 0z" fill-rule="evenodd"></path></svg></a>],
#  [<a class="mf mg by ax r iz mh a b cy" href="/tag/python">Python</a>],
#  [<a class="mf mg by ax r iz mh a b cy" href="/tag/web-scraping">Web Scraping</a>],
#  [<a class="mf mg by ax r iz mh a b cy" href="/tag/beautifulsoup">Beautifulsoup</a>],
#  [<a class="mf mg by ax r iz mh a b cy" href="/tag/web-crawling">Web Crawling</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_actions_footer-----4dde18468f1f---------------------clap_footer-" rel="noopener"><div class="c mk fc n o ml gz mm mn mo mp mq mr ms mt mu mv mw mx my bs"><div class="bg lq lr ls lt lu mz lw o hm fc n p na u hd ds t ak ba lx bk nb"><svg height="33" viewBox="0 0 33 33" width="33"><path d="M28.86 17.34l-3.64-6.4c-.3-.43-.71-.73-1.16-.8a1.12 1.12 0 0 0-.9.21c-.62.5-.73 1.18-.32 2.06l1.22 2.6 1.4 2.45c2.23 4.09 1.51 8-2.15 11.66a9.6 9.6 0 0 1-.8.71 6.53 6.53 0 0 0 4.3-2.1c3.82-3.82 3.57-7.87 2.05-10.39zm-6.25 11.08c3.35-3.35 4-6.78 1.98-10.47L21.2 12c-.3-.43-.71-.72-1.16-.8a1.12 1.12 0 0 0-.9.22c-.62.49-.74 1.18-.32 2.06l1.72 3.63a.5.5 0 0 1-.81.57l-8.91-8.9a1.33 1.33 0 0 0-1.89 1.88l5.3 5.3a.5.5 0 0 1-.71.7l-5.3-5.3-1.49-1.49c-.5-.5-1.38-.5-1.88 0a1.34 1.34 0 0 0 0 1.89l1.49 1.5 5.3 5.28a.5.5 0 0 1-.36.86.5.5 0 0 1-.36-.15l-5.29-5.29a1.34 1.34 0 0 0-1.88 0 1.34 1.34 0 0 0 0 1.89l2.23 2.23L9.3 21.4a.5.5 0 0 1-.36.85.5.5 0 0 1-.35-.14l-3.32-3.33a1.33 1.33 0 0 0-1.89 0 1.32 1.32 0 0 0-.39.95c0 .35.14.69.4.94l6.39 6.4c3.53 3.53 8.86 5.3 12.82 1.35zM12.73 9.26l5.68 5.68-.49-1.04c-.52-1.1-.43-2.13.22-2.89l-3.3-3.3a1.34 1.34 0 0 0-1.88 0 1.33 1.33 0 0 0-.4.94c0 .22.07.42.17.61zm14.79 19.18a7.46 7.46 0 0 1-6.41 2.31 7.92 7.92 0 0 1-3.67.9c-3.05 0-6.12-1.63-8.36-3.88l-6.4-6.4A2.31 2.31 0 0 1 2 19.72a2.33 2.33 0 0 1 1.92-2.3l-.87-.87a2.34 2.34 0 0 1 0-3.3 2.33 2.33 0 0 1 1.24-.64l-.14-.14a2.34 2.34 0 0 1 0-3.3 2.39 2.39 0 0 1 3.3 0l.14.14a2.33 2.33 0 0 1 3.95-1.24l.09.09c.09-.42.29-.83.62-1.16a2.34 2.34 0 0 1 3.3 0l3.38 3.39a2.17 2.17 0 0 1 1.27-.17c.54.08 1.03.35 1.45.76.1-.55.41-1.03.9-1.42a2.12 2.12 0 0 1 1.67-.4 2.8 2.8 0 0 1 1.85 1.25l3.65 6.43c1.7 2.83 2.03 7.37-2.2 11.6zM13.22.48l-1.92.89 2.37 2.83-.45-3.72zm8.48.88L19.78.5l-.44 3.7 2.36-2.84zM16.5 3.3L15.48 0h2.04L16.5 3.3z" fill-rule="evenodd"></path></svg></div></div></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/twitter?source=post_actions_footer---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M22.05 7.54a4.47 4.47 0 0 0-3.3-1.46 4.53 4.53 0 0 0-4.53 4.53c0 .35.04.7.08 1.05A12.9 12.9 0 0 1 5 6.89a5.1 5.1 0 0 0-.65 2.26c.03 1.6.83 2.99 2.02 3.79a4.3 4.3 0 0 1-2.02-.57v.08a4.55 4.55 0 0 0 3.63 4.44c-.4.08-.8.13-1.21.16l-.81-.08a4.54 4.54 0 0 0 4.2 3.15 9.56 9.56 0 0 1-5.66 1.94l-1.05-.08c2 1.27 4.38 2.02 6.94 2.02 8.3 0 12.86-6.9 12.84-12.85.02-.24 0-.43 0-.65a8.68 8.68 0 0 0 2.26-2.34c-.82.38-1.7.62-2.6.72a4.37 4.37 0 0 0 1.95-2.51c-.84.53-1.81.9-2.83 1.13z"></path></svg></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="//medium.com/p/4dde18468f1f/share/facebook?source=post_actions_footer---------------------------" rel="noopener nofollow" target="_blank"><svg class="q" height="29" width="29"><path d="M23.2 5H5.8a.8.8 0 0 0-.8.8V23.2c0 .44.35.8.8.8h9.3v-7.13h-2.38V13.9h2.38v-2.38c0-2.45 1.55-3.66 3.74-3.66 1.05 0 1.95.08 2.2.11v2.57h-1.5c-1.2 0-1.48.57-1.48 1.4v1.96h2.97l-.6 2.97h-2.37l.05 7.12h5.1a.8.8 0 0 0 .79-.8V5.8a.8.8 0 0 0-.8-.79"></path></svg></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=post_actions_footer--------------------------bookmark_sidebar-" rel="noopener"><svg height="25" viewBox="0 0 25 25" width="25"><path d="M19 6a2 2 0 0 0-2-2H8a2 2 0 0 0-2 2v14.66h.01c.01.1.05.2.12.28a.5.5 0 0 0 .7.03l5.67-4.12 5.66 4.13a.5.5 0 0 0 .71-.03.5.5 0 0 0 .12-.29H19V6zm-6.84 9.97L7 19.64V6a1 1 0 0 1 1-1h9a1 1 0 0 1 1 1v13.64l-5.16-3.67a.49.49 0 0 0-.68 0z" fill-rule="evenodd"></path></svg></a>],
#  [<a href="/@yunhanh?source=follow_footer--------------------------follow_footer-" rel="noopener"><img alt="Hannah Huang" class="r fc cq nl" height="80" src="https://miro.medium.com/fit/c/160/160/1*Vy9pmdUSKQjWdPz79tfaOw@2x.jpeg" width="80"/></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="/@yunhanh?source=follow_footer--------------------------follow_footer-" rel="noopener">Hannah Huang</a>],
#  [<a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer-b3c4a67e76b6-------------------------follow_footer-" rel="noopener">Follow</a>],
#  [<a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer-b3c4a67e76b6-------------------------follow_footer-" rel="noopener">Follow</a>],
#  [<a href="https://levelup.gitconnected.com/?source=follow_footer--------------------------follow_footer-" rel="noopener"><img alt="Level Up Coding" class="bt nl cq" height="80" src="https://miro.medium.com/fit/c/160/160/1*5D9oYBd58pyjMkV_5-zXXQ.jpeg" width="80"/></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://levelup.gitconnected.com/?source=follow_footer--------------------------follow_footer-" rel="noopener">Level Up Coding</a>],
#  [<a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer--------------------------follow_footer-" rel="noopener">Follow</a>],
#  [<a class="ll bq az ba br bj bk bs bi bt as b at au av aw bu bv bw bx by bl" href="https://medium.com/m/signin?operation=register&amp;redirect=https%3A%2F%2Flevelup.gitconnected.com%2Fquick-web-scraping-with-python-beautiful-soup-4dde18468f1f&amp;source=follow_footer--------------------------follow_footer-" rel="noopener">Follow</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi gn go bl bm fp fq" href="https://medium.com/p/4dde18468f1f/responses/show?source=follow_footer--------------------------follow_footer-" rel="noopener"><span class="nz oa lt"><div class="iy ob bt r kp cb"><span class="az">See responses (1)</span></div></span></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/about?autoplay=1&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener"><h4 class="pg ph pi as id at nu pj pk r">Discover <!-- -->Medium</h4></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi bl bm pe pf pn" href="https://medium.com/about?autoplay=1&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener">Watch</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/topics?source=post_page-----4dde18468f1f----------------------" rel="noopener"><h4 class="pg ph pi as id at nu pj pk r">Make <!-- -->Medium<!-- --> yours</h4></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi bl bm pe pf pn" href="https://medium.com/topics?source=post_page-----4dde18468f1f----------------------" rel="noopener">Explore</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/membership?source=post_page-----4dde18468f1f----------------------" rel="noopener"><h4 class="pg ph pi as id at nu pj pk r">Become a member</h4></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi bl bm pe pf pn" href="https://medium.com/membership?source=post_page-----4dde18468f1f----------------------" rel="noopener">Upgrade</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi pc pd bl bm pe pf" href="https://medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener"><svg class="ph" height="22" viewBox="0 0 111.5 22" width="112"><path d="M56.3 19.5c0 .4 0 .5.3.7l1.5 1.4v.1h-6.5V19c-.7 1.8-2.4 3-4.3 3-3.3 0-5.8-2.6-5.8-7.5 0-4.5 2.6-7.6 6.3-7.6 1.6-.1 3.1.8 3.8 2.4V3.2c0-.3-.1-.6-.3-.7l-1.4-1.4V1l6.5-.8v19.3zm-4.8-.8V9.5c-.5-.6-1.2-.9-1.9-.9-1.6 0-3.1 1.4-3.1 5.7 0 4 1.3 5.4 3 5.4.8.1 1.6-.3 2-1zm9.1 3.1V9.4c0-.3-.1-.6-.3-.7l-1.4-1.5v-.1h6.5v12.5c0 .4 0 .5.3.7l1.4 1.4v.1h-6.5zm-.2-19.2C60.4 1.2 61.5 0 63 0c1.4 0 2.6 1.2 2.6 2.6S64.4 5.3 63 5.3a2.6 2.6 0 0 1-2.6-2.7zm22.5 16.9c0 .4 0 .5.3.7l1.5 1.4v.1h-6.5v-3.2c-.6 2-2.4 3.4-4.5 3.4-2.9 0-4.4-2.1-4.4-6.2 0-1.9 0-4.1.1-6.5 0-.3-.1-.5-.3-.7L67.7 7v.1H74v8c0 2.6.4 4.4 2 4.4.9-.1 1.7-.6 2.1-1.3V9.5c0-.3-.1-.6-.3-.7l-1.4-1.5v-.2h6.5v12.4zm22 2.3c0-.5.1-6.5.1-7.9 0-2.6-.4-4.5-2.2-4.5-.9 0-1.8.5-2.3 1.3.2.8.3 1.7.3 2.5 0 1.8-.1 4.2-.1 6.5 0 .3.1.5.3.7l1.5 1.4v.1H96c0-.4.1-6.5.1-7.9 0-2.7-.4-4.5-2.2-4.5-.9 0-1.7.5-2.2 1.3v9c0 .4 0 .5.3.7l1.4 1.4v.1h-6.5V9.5c0-.3-.1-.6-.3-.7l-1.4-1.5v-.2h6.5v3.1a4.6 4.6 0 0 1 4.6-3.4c2.2 0 3.6 1.2 4.2 3.5.7-2.1 2.7-3.6 4.9-3.5 2.9 0 4.5 2.2 4.5 6.2 0 1.9-.1 4.2-.1 6.5-.1.3.1.6.3.7l1.4 1.4v.1h-6.6zm-81.4-2l1.9 1.9v.1h-9.8v-.1l2-1.9c.2-.2.3-.4.3-.7V7.3c0-.5 0-1.2.1-1.8L11.4 22h-.1L4.5 6.8c-.1-.4-.2-.4-.3-.6v10c-.1.7 0 1.3.3 1.9l2.7 3.6v.1H0v-.1L2.7 18c.3-.6.4-1.3.3-1.9v-11c0-.5-.1-1.1-.5-1.5L.7 1.1V1h7l5.8 12.9L18.6 1h6.8v.1l-1.9 2.2c-.2.2-.3.5-.3.7v15.2c0 .2.1.5.3.6zm7.6-5.9c0 3.8 1.9 5.3 4.2 5.3 1.9.1 3.6-1 4.4-2.7h.1c-.8 3.7-3.1 5.5-6.5 5.5-3.7 0-7.2-2.2-7.2-7.4 0-5.5 3.5-7.6 7.3-7.6 3.1 0 6.4 1.5 6.4 6.2v.8h-8.7zm0-.8h4.3v-.8c0-3.9-.8-4.9-2-4.9-1.4.1-2.3 1.6-2.3 5.7z"></path></svg></a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi fo bl bm pe pf" href="https://medium.com/about?autoplay=1&amp;source=post_page-----4dde18468f1f----------------------" rel="noopener">About</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi fo bl bm pe pf" href="https://help.medium.com/?source=post_page-----4dde18468f1f----------------------" rel="noopener">Help</a>],
#  [<a class="dc dd bb bc bd be bf bg bh bi fo bl bm pe pf" href="https://medium.com/policy/9db0094a1e0f?source=post_page-----4dde18468f1f----------------------" rel="noopener">Legal</a>]]
